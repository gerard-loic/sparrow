# %% [markdown]
# Librairies :
#
# https://www.kaggle.com/datasets/mexwell/mahjong/data
# https://universe.roboflow.com/roboflow100vl-full/mahjong-vtacs-mexax-xwwj
# https://github.com/Camerash/mahjong-dataset
# https://universe.roboflow.com/rf100-vl/mahjong-vtacs-mexax-m4vyu-sjtd
#
#
# https://github.com/lissa2077/Mahjong-Detection
